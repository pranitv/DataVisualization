# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[1,4,5])
plt.plot([4,5,6],[3,2,3])
plt.legend(['Data set 1','Data set 2'])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('this is plot table')
plt.savefig('exported image')
#plt.show()
