# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# 5     Afghanistan      Asia  1977          38.438    14880372    786.113360
# 6     Afghanistan      Asia  1982          39.854    12881816    978.011439
# 7     Afghanistan      Asia  1987          40.822    13867957    852.395945
# 8     Afghanistan      Asia  1992          41.674    16317921    649.341395
# 9     Afghanistan      Asia  1997          41.763    22227415    635.341351
# 10    Afghanistan      Asia  2002          42.129    25268405    726.734055
# ...

# %%
set(data.continent)
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania'}

# %%
data_2007 = data[data.year==2007]
asia_2007 = data_2007[data_2007.continent=='Asia']
europe_2007 = data_2007[data_2007.continent =='Europe']
asia_2007.head()
europe_2007.head()
# Out:
#                     country continent  year  lifeExpectancy  population  \
# 23                  Albania    Europe  2007          76.423     3600523
# 83                  Austria    Europe  2007          79.829     8199783
# 119                 Belgium    Europe  2007          79.441    10392226
# 155  Bosnia and Herzegovina    Europe  2007          74.852     4552198
# 191                Bulgaria    Europe  2007          73.005     7322858
#
#      gdpPerCapita
# 23    5937.029526
# 83   36126.492700
# 119  33692.605080
# 155   7446.298803
# 191  10680.792820

# %%
len(set(asia_2007.country))
# Out:
# 33

# %%
len(set(europe_2007.country))
# Out:
# 30

# %%
print(asia_2007.gdpPerCapita.mean())
print(asia_2007.gdpPerCapita.median())
print(europe_2007.gdpPerCapita.mean())
print(europe_2007.gdpPerCapita.median())
# Out:
# 12473.02687013333
# 4471.061906
# 25054.481635933327
# 28054.06579

# %%
plt.subplot(2,1,1)
plt.hist(asia_2007.gdpPerCapita,20,range =(0,50000),edgecolor = 'Black')
plt.ylabel('Asia')
plt.subplot(2,1,2)
plt.hist(europe_2007.gdpPerCapita,20,range =(0,50000),edgecolor = 'Black')
plt.ylabel('Europe')
plt.title('GDP comparision')
plt.show()

# %%
india = asia_2007[asia_2007.country =='India']
india
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 707   India      Asia  2007          64.698  1110396331   2452.210407

# %%
data_1997 = data[data.year == 1997]
americas_1997 = data_1997[data_1997.continent =='Americas']
europe_1997 = data_1997[data_1997.continent =='Europe']
plt.subplot(2,1,1)
plt.hist(americas_1997.lifeExpectancy,20,range =(55,85))
plt.title('Americas')
plt.subplot(2,1,2)
plt.hist(europe_1997.lifeExpectancy,20,range = (55,85))
plt.title('Europe')
# Out:
# Text(0.5, 1.0, 'Europe')

# %%
americas_1997[americas_1997.lifeExpectancy<65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 141  Bolivia  Americas  1997          62.050     7693188   3326.143191
# 645    Haiti  Americas  1997          56.671     6913545   1341.726931

# %%
 plt.plot(data.year,data[data.country=='India'])
 plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-34b0b0e60186> in <module>
# ----> 1 plt.plot(data.year,data[data.country=='India'])
#       2 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
plt.plot(data.year,data[data.country=='India'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f7bd9c9faa39> in <module>
# ----> 1 plt.plot(data.year,data[data.country=='India'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
india = data[data.country=='India']
plt.plot(india.year,india.gdpPerCapita)
plt.show()
